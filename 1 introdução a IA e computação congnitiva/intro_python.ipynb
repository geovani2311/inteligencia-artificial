# %% [markdown]
# <a href="https://colab.research.google.com/github/geovani2311/inteligencia-artificial/blob/main/inteligencia_artificial/intro_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world
